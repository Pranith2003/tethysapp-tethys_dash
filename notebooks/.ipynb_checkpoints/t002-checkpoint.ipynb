# %%
import requests

# %%
base_url = "http://ggst-api.geoglows.org"
url = f"{base_url}/api/fetchDates/arab/grace"

# %%
response = requests.get(url)

# %%
response.json().get('dates', [])
# Out:
# ['2002-04-17T12:00:00.000Z',
#  '2002-05-10T12:00:00.000Z',
#  '2002-08-16T12:00:00.000Z',
#  '2002-09-16T00:00:00.000Z',
#  '2002-10-16T12:00:00.000Z',
#  '2002-11-16T00:00:00.000Z',
#  '2002-12-16T12:00:00.000Z',
#  '2003-01-16T12:00:00.000Z',
#  '2003-02-15T00:00:00.000Z',
#  '2003-03-16T12:00:00.000Z',
#  '2003-04-16T00:00:00.000Z',
#  '2003-05-11T12:00:00.000Z',
#  '2003-07-16T12:00:00.000Z',
#  '2003-08-16T12:00:00.000Z',
#  '2003-09-16T00:00:00.000Z',
#  '2003-10-16T00:00:00.000Z',
#  '2003-11-16T00:00:00.000Z',
#  '2003-12-16T12:00:00.000Z',
#  '2004-01-07T12:00:00.000Z',
#  '2004-02-17T00:00:00.000Z',
#  '2004-03-16T12:00:00.000Z',
#  '2004-04-16T00:00:00.000Z',
#  '2004-05-16T12:00:00.000Z',
#  '2004-06-16T00:00:00.000Z',
#  '2004-07-16T12:00:00.000Z',
#  '2004-08-16T12:00:00.000Z',
#  '2004-09-16T00:00:00.000Z',
#  '2004-10-16T12:00:00.000Z',
#  '2004-11-16T00:00:00.000Z',
#  '2004-12-16T12:00:00.000Z',
#  '2005-01-16T12:00:00.000Z',
#  '2005-02-15T00:00:00.000Z',
# ...
