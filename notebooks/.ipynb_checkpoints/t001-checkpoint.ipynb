# %%
import intake

# %%
intake.registry
# Out:
# <Intake driver registry>

# %%
intake.open_list_regions
# Out:
# tethysapp.tethysdash.intake_plugins.list_regions.ListRegionsDataSource

# %%
from pprint import pprint

# %%
import importlib.metadata as m 
pprint(m.entry_points(group='intake.drivers'))
# Out:
# (EntryPoint(name='csv', value='intake.source.csv:CSVSource', group='intake.drivers'),
#  EntryPoint(name='jsonfiles', value='intake.source.jsonfiles:JSONFileSource', group='intake.drivers'),
#  EntryPoint(name='ndzarr', value='intake.source.zarr:ZarrArraySource', group='intake.drivers'),
#  EntryPoint(name='numpy', value='intake.source.npy:NPySource', group='intake.drivers'),
#  EntryPoint(name='textfiles', value='intake.source.textfiles:TextFilesSource', group='intake.drivers'),
#  EntryPoint(name='tiled_cat', value='intake.source.tiled:TiledCatalog', group='intake.drivers'),
#  EntryPoint(name='fetch_dates', value='tethysapp.tethysdash.intake_plugins.fetch_dates:FetchDatesDataSource', group='intake.drivers'),
#  EntryPoint(name='geo_glo_ws', value='tethysapp.tethysdash.intake_plugins.geo_glo_ws:GeoGloWSDataSource', group='intake.drivers'),
#  EntryPoint(name='geos_line_chart', value='tethysapp.tethysdash.intake_plugins.geoslinechart:GeoSLineChart', group='intake.drivers'),
# ...
